# %%
import pandas as pd
import numpy as np

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4 # Display settings
#
# ModuleNotFoundError: No module named 'pandas'

# %%
dataset1 = pd.read_csv("../data/dataset1.csv")
dataset2 = pd.read_csv("../data/dataset2.csv")

# %%
print(dataset1.shape)
print(dataset2.shape)
# Out:
# (29999, 23)
# (29999, 35)

# %%
dataset1.head()
# Out:
#      post_id  account_id account_type  follower_count media_type  \
# 0  IG0000001           7        brand            3551       reel
# 1  IG0000002          20      creator           31095      image
# 2  IG0000003          15        brand            8167       reel
# 3  IG0000004          11      creator            9044   carousel
# 4  IG0000005           8      creator           15986       reel
#
#   content_category traffic_source  has_call_to_action        post_datetime  \
# 0       Technology      Home Feed                   1  2024-11-30 06:00:00
# 1          Fitness       Hashtags                   1  2025-08-15 15:00:00
# 2           Beauty     Reels Feed                   0  2025-09-11 16:00:00
# 3            Music       External                   0  2025-09-18 03:00:00
# 4       Technology        Profile                   0  2025-03-21 09:00:00
#
#     post_date  post_hour day_of_week  likes  comments  shares  saves  reach  \
# ...

# %%
dataset2.head()
# Out:
#      post_id  account_id account_type  follower_count media_type  \
# 0  IG0008958           1        brand            9461   carousel
# 1  IG0005710           1      creator            9461   carousel
# 2  IG0006615           1      creator            9461      image
# 3  IG0022743           1      creator            9461      image
# 4  IG0016262           1        brand            9461       reel
#
#   content_category traffic_source  has_call_to_action        post_datetime  \
# 0        Lifestyle       External                   0  2024-11-19 05:00:00
# 1           Beauty        Profile                   0  2024-11-19 07:00:00
# 2       Technology        Explore                   1  2024-11-19 07:00:00
# 3        Lifestyle      Home Feed                   0  2024-11-19 10:00:00
# 4        Lifestyle       External                   0  2024-11-19 12:00:00
#
#     post_date  post_hour day_of_week  likes  comments  shares  saves  reach  \
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   post_id                   29999 non-null  str
#  1   account_id                29999 non-null  int64
#  2   account_type              29999 non-null  str
#  3   follower_count            29999 non-null  int64
#  4   media_type                29999 non-null  str
#  5   content_category          29999 non-null  str
#  6   traffic_source            29999 non-null  str
#  7   has_call_to_action        29999 non-null  int64
#  8   post_datetime             29999 non-null  str
#  9   post_date                 29999 non-null  str
#  10  post_hour                 29999 non-null  int64
#  11  day_of_week               29999 non-null  str
#  12  likes                     29999 non-null  int64
#  13  comments                  29999 non-null  int64
# ...

# %%
dataset2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 29999 entries, 0 to 29998
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   post_id                       29999 non-null  str
#  1   account_id                    29999 non-null  int64
#  2   account_type                  29999 non-null  str
#  3   follower_count                29999 non-null  int64
#  4   media_type                    29999 non-null  str
#  5   content_category              29999 non-null  str
#  6   traffic_source                29999 non-null  str
#  7   has_call_to_action            29999 non-null  int64
#  8   post_datetime                 29999 non-null  str
#  9   post_date                     29999 non-null  str
#  10  post_hour                     29999 non-null  int64
#  11  day_of_week                   29999 non-null  str
#  12  likes                         29999 non-null  int64
# ...

# %%
dataset1.describe(include="all")
# Out:
#           post_id    account_id account_type  follower_count media_type  \
# count       29999  29999.000000        29999    29999.000000      29999
# unique      29999           NaN            2             NaN          3
# top     IG0000001           NaN      creator             NaN      image
# freq            1           NaN        20944             NaN      11927
# mean          NaN     10.567819          NaN    10278.305477        NaN
# std           NaN      5.763952          NaN     6691.862669        NaN
# min           NaN      1.000000          NaN     3083.000000        NaN
# 25%           NaN      6.000000          NaN     5824.000000        NaN
# 50%           NaN     11.000000          NaN     9044.000000        NaN
# 75%           NaN     16.000000          NaN    10739.000000        NaN
# max           NaN     20.000000          NaN    31095.000000        NaN
#
#        content_category traffic_source  has_call_to_action  \
# ...

# %%
dataset2.describe(include="all")
# Out:
#           post_id    account_id account_type  follower_count media_type  \
# count       29999  29999.000000        29999    29999.000000      29999
# unique      29999           NaN            2             NaN          3
# top     IG0008958           NaN      creator             NaN      image
# freq            1           NaN        20944             NaN      11927
# mean          NaN     10.567819          NaN    10278.305477        NaN
# std           NaN      5.763952          NaN     6691.862669        NaN
# min           NaN      1.000000          NaN     3083.000000        NaN
# 25%           NaN      6.000000          NaN     5824.000000        NaN
# 50%           NaN     11.000000          NaN     9044.000000        NaN
# 75%           NaN     16.000000          NaN    10739.000000        NaN
# max           NaN     20.000000          NaN    31095.000000        NaN
#
#        content_category traffic_source  has_call_to_action  \
# ...

# %%
dataset1.isnull().sum()
# Out:
# post_id                     0
# account_id                  0
# account_type                0
# follower_count              0
# media_type                  0
# content_category            0
# traffic_source              0
# has_call_to_action          0
# post_datetime               0
# post_date                   0
# post_hour                   0
# day_of_week                 0
# likes                       0
# comments                    0
# shares                      0
# saves                       0
# reach                       0
# impressions                 0
# engagement_rate             0
# followers_gained            0
# caption_length              0
# hashtags_count              0
# performance_bucket_label    0
# dtype: int64

# %%
dataset2.isnull().sum()
# Out:
# post_id                          0
# account_id                       0
# account_type                     0
# follower_count                   0
# media_type                       0
# content_category                 0
# traffic_source                   0
# has_call_to_action               0
# post_datetime                    0
# post_date                        0
# post_hour                        0
# day_of_week                      0
# likes                            0
# comments                         0
# shares                           0
# saves                            0
# reach                            0
# impressions                      0
# engagement_rate                  0
# followers_gained                 0
# caption_length                   0
# hashtags_count                   0
# performance_bucket_label         0
# weekend_flag                     0
# month                            0
# week_of_year                     0
# quarter                          0
# ...

# %%
dataset1.duplicated().sum()
# Out:
# np.int64(0)

# %%
dataset2.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(dataset1.columns.tolist())
# Out:
# ['post_id', 'account_id', 'account_type', 'follower_count', 'media_type', 'content_category', 'traffic_source', 'has_call_to_action', 'post_datetime', 'post_date', 'post_hour', 'day_of_week', 'likes', 'comments', 'shares', 'saves', 'reach', 'impressions', 'engagement_rate', 'followers_gained', 'caption_length', 'hashtags_count', 'performance_bucket_label']

# %%
print(dataset2.columns.tolist())
# Out:
# ['post_id', 'account_id', 'account_type', 'follower_count', 'media_type', 'content_category', 'traffic_source', 'has_call_to_action', 'post_datetime', 'post_date', 'post_hour', 'day_of_week', 'likes', 'comments', 'shares', 'saves', 'reach', 'impressions', 'engagement_rate', 'followers_gained', 'caption_length', 'hashtags_count', 'performance_bucket_label', 'weekend_flag', 'month', 'week_of_year', 'quarter', 'total_posts_count', 'avg_likes_last_10_posts', 'avg_comments_last_10_posts', 'avg_engagement_last_10_posts', 'days_since_last_post', 'hours_since_last_post', 'posting_frequency_per_week', 'viral_flag']

# %%
import pandas as pd

df = pd.read_csv("backend/ml/data/dataset2.csv")

print(df["viral_flag"].value_counts())
print(df["viral_flag"].value_counts(normalize=True))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv("backend/ml/data/dataset2.csv")
#       4
#
# ModuleNotFoundError: No module named 'pandas'
